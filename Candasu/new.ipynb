# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model, save_model, load_model
from tensorflow.keras.layers import Input, Embedding, SimpleRNN, Dense, LSTM, GRU, Bidirectional, Dropout
from sklearn.model_selection import train_test_split

# %%
old_kannada_sentences= ['ಒಡವೆಯನರ್ಥಿಗಿತ್ತೆನವನೀತಳಮಂ',
                        'ನಗೆಮೊಗದೊಳ್',
                        'ನಂದನವನಂಗಳೊಳಂ',
                        'ನಲ್ಲರೊಳ್ಮೊಗಂ',
                  'ಗುರುಗಿತ್ತೆನೀಗಳೊಂ',
                  'ದಡೆಕೆಯುಮಿಲ್ಲ',
                  'ಕೈಯೊಳೆರೆದಂ',
                  'ಶ್ರುತಪಾರಗನೆಂತು',
                  'ಸಂತಸಂ',
                  'ಬಡಿಸುವೆನಿನ್ನಿದೊಂದು',
                  'ಧನುವಿರ್ದುದು',
                  'ದಿವ್ಯಶರಾಳಿಯಿರ್ದುದಿ',
                  'ಲ್ಲೊಡಮೆ',
                  'ಸಮಂತು',
                  'ಪೇರವರೊಳಾವುದನೀವುದೊ',
                  'ಕುಂಭಸಂಭವ',
                  'ಅಂತೆಂಬನಾರ್ಗೆ',
                  'ಪಿರಿದುಂ',
                  'ಭ್ರಾಂತು',
                  'ದಲೇಂ',
                  'ದ್ರೋಣನೆಂಬನೇಂ',
                  'ಪಾರ್ವನೆ',
                  'ಪೇೞೆಂತೆನಗೆ',
                  'ಕೆಳೆಯನೇ',
                  'ನೂಂಕಂತಪ್ಪನನಱಿಯೆನೆಂದು',
                  'ಸಭೆಯೊಳ್',
                  'ನುಡಿದಂ',
                  'ಅಱಿಯಿರೆ',
                  'ನೀಮುಮಾಮುಮೊಡನೋದಿದೆವೆಂಬುದನಣ್ಣ',
                  'ನಿನ್ನ',
                  'ನಾನಱಿಯೆನದೆಲ್ಲಿ',
                  'ಕಂಡೆಯೊ',
                  'ಮಹೀಪತಿಗಂ',
                  'ದ್ವಿಜವಂಶಜಂಗಮೇ',
                  'ಕೆಳೆಯಿಂತು',
                  'ನಾಣಿಲಿಗರಪ್ಪರೆ',
                  'ಮಾನಸರೆಂಬ',
                  'ಮಾತುಗಳ್',
                  'ನೆಱೆಗೊಳೆ',
                  'ಕುಂಭಸಂಭವನನಾ',
                  'ದ್ರುಪದಂ',
                  'ಕಡುಸಿಗ್ಗು',
                  'ಮಾಡಿದಂ',
                  'ಬಗೆದೆನೀಗಳೀ',
                  'ಕಲ್ಪಮೀಶಾನ',
                  'ಚಲಲ್ಲುಳಿತಕೇತನಂ',
                  'ಸುರವಿಮಾನಮಾ',
                  'ಶ್ರೀಪ್ರಭಂ',
                  'ಸಲೀಲವದನಾರವಿಂದಮಿದು',
                  'ವಿತ್ರಸ್ತಕರ್ಮರಿಪುವ',
                  'ಜಗತ್ತ್ರಯದೀಪಕನ',
                  'ಕಾಣ್ಕೆಗೊಳಗಾದುದು',
                  'ವೇತ್ರಾಸನಝಲ್ಲರೀಮೃದಂಗಸಮಾನಂ',
                  'ಹೇಯಂಗಳ್',
                  'ಖಳಕರ್ಮಬಂಧನಕರ',
                  'ಕ್ರೋಧಾದಿಗಳ್',
                  'ದುರಿತೇಂಧನಾನಳಲಸದ್ರತ್ನತ್ರಯಂಗಳ್',
                  'ಸುಖೋಪಾಯಂಗಳ್ಗಡಿವೆಂದು',
                  'ಭವ್ಯಜನಮಂ',
                  'ಕಣ್ಣೂಱಿ',
                  'ಕಲ್ಪಿಪ್ಪುಪಾಧ್ಯಾಯಜ್ರ್ಯೋತಿಸುಗೆಮ್ಮ',
                  'ಚಿತ್ತಗೃಹದೊಳ್ರತ್ನತ್ರಯಜ್ಯೋತಿಯಂ',
                  'ತಡವಪ್ಪುದೊಂದು',
                  'ಮೊಗದೊಳ್',
                  'ಮಱುಕಂ',
                  'ದೊರೆಕೊಳ್ವುದೊಂದು',
                  'ನಾಣ್ಗೆಡೆಗುಡದಿರ್ಪುದೊಂದು',
                  'ನುಡಿಗಳ್',
                  'ಮೊಱೆಯಂ',
                  'ಮಱೆಯಿಪ್ಪುದೊಂದು',
                  'ಕಳ್ಗುಡಿದವರಂದಮಿಂತು',
                  'ಸಾರ್ವುದದರ್ಕೆ',
                  'ಸಂದೆಯಂ',
                  'ಜಲಕ್ಕನೀಗಳಱಿದೆಂ',
                  'ಕಳ್ಳೊಡವುಟ್ಟಿತೆಂಬುದಂ',
                  'ವರಮೆಂಬವೊಲಾಂಬರಮುಂಟೆ',
                  'ದಳವೊಡನೋದಿದೊಂದು',
                  'ಕೊಲಲ್ಕೆನಗಾಗದೀ',
                  'ವಳಯದೊಳೆನ್ನನೇೞಿಸಿದ',
                  'ನಿನ್ನನನಾಕುಳಮೆನ್ನ',
                  'ಲಳಿತಾಳಂಕರಣಪ್ರಸನ್ನರಸವದ್ಗೇಯಂಗಳೊಳ್',
                  'ಮೂಡುತುಂ',
                  'ಮುೞುಗುತ್ತುಂ',
                  'ಖಚರೀಜನಾನನನವಾಂಭೋಜಂಗಳೊಳ್',
                  'ಕಂಪನೀೞ್ಕೊಳುತುಂ',
                  'ನಂದನರಾಜಿಯೊಳ್ನಲಿಯುತುಂ',
                  'ತದ್ರಾಜಹಂಸಂ',
                  'ನಿರಾಲುಳಮೀ' ,
                  'ಮಾೞ್ಕೆಗಳಿಂದೆ',
                  'ಪೊೞ್ತುಗಳೆವಂ',
                  'ಇದು',
                  'ದೇವೇಂದ್ರಮುನೀಂದ್ರವಂದ್ಯಪರಮಜಿನೇಂದ್ರಮುಖಚಂದ್ರ',
                  'ವಾಕ್ಚಂದ್ರಿಕಾಪ್ರಸರಪ್ರಸಾದೋದೀರ್ಣ',
                  'ಸೂಕ್ತಿಕಲ್ಲೋಲಮಾಲಾಕೀರ್ಣ',
                  'ಕವಿತಾಗುಣಾರ್ಣವಪ್ರಣೀತಮಪ್ಪಾದಿಪುರಾಣದೊಳ್',
                  'ಮಹಾಬಳಕುಮಾರೋದಯವರ್ಣನಂ',
                  'ಪ್ರಥಮಾಶ್ವಾಸಂ',
                  'ಸರಸ್ವತೀಮಣಿಹಾ',
                  'ಕಟಕಕಟಿಸೂತ್ರಕುಂಡಲ',
                  'ಹಟತ್ಕಿರೀಟಾಂಗದಾದಿಮಣಿಭೂಷಣಭಾಜಟಳಿತಮೂರ್ತ್ಯುತ್ಕರ್ಷಂ',
                  'ಸ್ಫುಟಹರ್ಷಂ',
                  'ತನ್ನ',
                  'ವರ್ಷವರ್ಧನದಿನದೊಳ್',
                  'ಅತಿಪ್ರಚಂಡಮಆಡಳಿಕಮಹಾಸಾಮಂತಮಂತ್ರಿಪ್ರಧಾನಪುರೋಹಿತಾಂತರ್ವಂಶಿಕಾ',
                  'ಪರಿವಾರಪರಿವೃತಂ',
                  'ಉತ್ತುಂಗಸಿಂಹಾಸನಾಸೀನಂ',
                  'ಅಧಸ್ಥಿತಮಣಿಮಯಪೀಠವೇದಿಕಾವಿನ್ಯಸ್ತವಾಮಪಾದಂ',
                  'ಅಂಬರಾಚರಾಂಗನಾ',
                  'ಕರತಳಪಲ್ಲವೋಲ್ಲಸಿತ ',
                  'ಹೇಮಚಾಮರಪವನವಿಲೋಲದುಕೂಲವಸನಪರಿವೃತಂ',
                  'ಪಂಚರತ್ನಪ್ರಭಾಭಾಸುರವಿವಿಧವಿಭೂಷಣವಿರಚಿತ',
                  'ಸುರಶರಾಸನಂ',
                  'ಒಡ್ಡೋಗಲಂಗೊಟ್ಟಿರೆ',
                  'ಎರಡುಂ',
                  'ವಿದ್ಯಾಧಶ್ರೇಢಿಯ',
                  'ಖಚರಮಹೀಪಾಳಕರ್',
                  'ಸುತ್ತಲುಂ',
                  'ಬಂದಿರೆ',
                  'ನಾನಾತೋದ್ಯವಾದ್ಯಂಗಳನೆ',
                  'ಮೆಱೆದು',
                  'ಮೆಚ್ಚಂ',
                  'ಕೊಳಲ್ವಾದಕರ್ಬಂದಿರೆ',
                  'ವಂದಿವ್ರಾತಮೆತ್ತಂ',
                  'ಗೀತಾರಾವದಿಂದಂ',
                  'ನೆಱೆಯೆ',
                  'ನೆಱಗೊಳಲ್',
                  'ರಕ್ತಕಂಠೀಜನಂ',
                  'ಬಗೆಗೊಳಲಿರೆ',
                  'ಚೆಲ್ವಾದುದಾಸ್ಥಾನರಂಗಂ',
                  'ಶ್ರೀಮದಮರಾಂಗನಾನನ',
                  'ತಾಮರಸಾಮೋದ',
                  'ಮತ್ತಮಧುಕರನಾ',
                  'ಸರಸ್ವತೀಮಣಿಹಾರಂ',
                  'ಸುರಸೌಖ್ಯಾಮೃತರಸದೊಳ್',
                  'ಬಗೆದಾಗಳೆ',
                  'ವಾಹನದೇವಿಯರುಯ್ವರ',
                  'ಬಾಸಿಗಮೊಯ್ಯನೊಯ್ಯನಿ',
                  'ಮಸುಳ್ದುವಾಗುಳಿಯಾಯ್ತಿನಿತುಬ್ಬೆಗಂ',
                  'ತನ್ನಗಲ್ಕೆಗೆ',
                  'ನಾಕಲೋಕಚ್ಯುತಿಯನಾಗಳಱಿದು',
                  'ಮನದೊಳಳ್ಕಿ ಬೆಳ್ಕನೆವೋಗಿ',
                  'ಸಂತಸದ೦ತಮನೆಯ್ದಿ',
                  'ಸುರತಾಮೃತದೊಳ್',
                  'ತಣಿದೞ್ಕಱಿಂ',
                  'ಮೆಯ್ಗಳೆರಡಾದೊಡಮೇನಸುವೊಂದೆ',
                  'ನಿನಗೊರ್ವಂಗಲ್ಲವಸ್ಥಾ೦ತರಮಮರಜನಕ್ಕೆಲ್ಲಮೀ',
                  'ಬಗೆಗೊಂಡಭೀತಮನನರ್ಚಿಸಿ'
                ]

new_kannada_sentences = ['ಒಡವೆಯನ್ ಅರ್ಥಿಗೆ ಇತ್ತೆನ್ ಅವನೀತಳಮಂ',
                         'ನಗೆ ಮೊಗದೊಳ್',
                         'ನಂದನವನ ದೊಳ್',
                         'ನಲ್ಲರ ಓಳ್ ಮೊಗಂ',
                  'ಗುರುಗೆ ಇತ್ತೆನ್ ಈಗಳ್ ಒಂದು',
                  'ಅಡೆಕೆಯುಮ್ ಇಲ್ಲ',
                  'ಕೈಯೊಳ್ ಎರೆದಂ',
                  'ಶ್ರುತ ಪಾರಗನ್ ಎಂತು',
                  'ಸಂತಸಂ',
                  'ಬಡಿಸುವೆನ್ ಇನ್ನು ಇದೊಂದು',
                  'ಧನು ಇರ್ದುದು',
                  'ದಿವ್ಯಶರಾಳಿ ಇರ್ದುದು',
                  'ಇಲ್ಲ ಒಡಮೆ',
                  'ಸಮಂತು',
                  'ಪೇೞ್‌ ಅವರೊಳ್ ಆವುದನ್ ಈವುದೊ',
                  'ಕುಂಭಸಂಭವಂ',
                  'ಅಂತು ಎಂಬನ್ ಆರ್ಗೆ',
                  'ಪಿರಿದುಂ',
                  'ಭ್ರಾಂತು',
                  'ದಲೇಂ',
                  'ದ್ರೋಣನ್ ಎಂಬನ್ ಏಂ',
                  'ಪಾರ್ವನೆ',
                  'ಪೇೞ್‌ ಎಂತು ಎನಗೆ',
                  'ಕೆಳೆಯನೇ',
                  'ನೂಂಕು ಅಂತಪ್ಪನನ್ ಅಱಿಯೆನ್ ಎಂದು',
                  'ಸಭೆಯೊಳ್',
                  'ನುಡಿದಂ',
                  'ಅಱಿಯಿರೆ',
                  'ನೀಮುಮ್ ಆಮುಮ್ ಒಡನೆ ಓದಿದೆವು ಎಂಬುದನ್ ಅಣ್ಣ',
                  'ನಿನ್ನನ್',
                  'ಆನ್ ಅಱಿಯೆನ್ ಅದೆಲ್ಲಿ',
                  'ಕಂಡೆಯೊ',
                  'ಮಹೀಪತಿಗಂ',
                  'ದ್ವಿಜವಂಶಜಂಗಮ್' ,
                  'ಕೆಳೆ ಇಂತು',
                  'ನಾಣಿಲಿಗರ್ ಅಪ್ಪರೆ',
                  'ಮಾನಸರ್ ಎಂಬ',
                  'ಮಾತುಗಳ್',
                  'ನೆಱೆಗೊಳೆ',
                  'ಕುಂಭಸುಂಭವನನ್ ಆ',
                  'ದ್ರುಪದಂ',
                  'ಕಡುಸಿಗ್ಗು',
                  'ಮಾಡಿದಂ',
                  'ಈಗಳ್ ಬಗೆದೆನ್',
                  'ಕಲ್ಪಂ ಈಶಾನಂ',
                  'ಚಲತ್ ಲುಳಿತಕೇತನಂ',
                  'ಸುರವಿಮಾನಂ ಆ',
                  'ಶ್ರೀಪ್ರಭಂ',
                  'ಸಲೀಲ ವದನ ಅರವಿಂದಂ ಇದು',
                  'ಕರ್ಮರಿಪುವ ವಿತ್ರಸ್ತ',
                  'ಜಗತ್ ತ್ರಯ ದೀಪಕನ',
                  'ಕಾಣ್ಕೆಗೆ ಒಳಗಾದುದು',
                  'ವೇತ್ರ ಆಸನ ಝಲ್ಲರಿ ಮೃದಂಗ ಸಮಾನಂ',
                  'ಹೇಯಂಗಳ್',
                  'ಖಳ ಕರ್ಮಬಂಧನಕರ',
                  'ಕ್ರೋಧಾದಿಗಳ್',
                  'ದುರಿತ ಇಂಧನ ಲಸತ್ ರತ್ನತ್ರಯಂಗಳ್',
                  'ಸುಖೋಪಾಯಂಗಳ್ ಗಡ ಎಂದು',
                  'ಭವ್ಯಜನಮಂ',
                  'ಕಣ್ಣೂಱಿ',
                  'ಕಲ್ಪಿಪ್ಪ ಉಪಾಧ್ಯಾಯರ್ ಜ್ಯೋತಿಸುಗೆ ಎಮ್ಮ',
                  'ಚಿತ್ತಗೃಹದೊಳ್ ರತ್ನತ್ರಯಜ್ಯೋತಿಯಂ',
                  'ತಡವಪ್ಪುದು ಒಂದು',
                  'ಮೊಗದೊಳ್',
                  'ಮಱುಕಂ',
                  'ದೊರೆಕೊಳ್ವುದು ಒಂದು',
                  'ನಾಣ್ಗೆ ಎಡೆಗುಡದೆ ಇರ್ಪುದು ಒಂದು',
                  'ನುಡಿಗಳ್',
                  'ನುಡಿಗಳ್',
                  'ಮಱೆಯಿಪ್ಪುದು ಒಂದು',
                  'ಕಳ್ ಕುಡಿದವರ್ ಅಂದಮ್ ಇಂತು',
                  'ಸಾರ್ವುದು ಅದರ್ಕೆ',
                  'ಸಂದೆಯಂ',
                  'ಜಲಕ್ಕನೆ ಈಗಳ್ ಅಱಿದೆಂ',
                  'ಕಳ್ಳೊಡವುಟ್ಟಿತೆಂಬುದಂ',
                  'ವರಮ್ ಎಂಬವೊಲ್ ಆಂಬರಮ್ ಉಂಟೆ',
                  'ಅಳವು ಒಡನೆ ಓದಿದ ಒಂದು',
                  'ಕೊಲಲ್ಕೆ ಎನಗೆ ಆಗದೆ ಈ',
                  'ವಳಯದೊಳ್ ಎನ್ನನ್ ಏೞಿಸಿದ',
                  'ನಿನ್ನನ್ ಅನಾಕುಳಮ್ ಎನ್ನ',
                  'ಲಲಿತ ಅಲಂಕರಣ ರಸವತ್ ಗೇಯಂಗಳೊಳ್',
                  'ಮೂಡುತುಂ',
                  'ಮುೞುಗುತ್ತುಂ',
                  'ಖಚರೀಜನ ಆನನ ನವ ಅಂಭೋಜಂಗಳೊಳ್',
                  'ಕಂಪನ್ ಈೞ್ಕೊಳುತುಂ',
                  'ನಂದನರಾಜಿಯೊಳ್',
                  'ತತ್ ರಾಜಹಂಸಂ',
                  'ನಿರ್ ಆಕುಳಂ ಈ',
                  'ಮಾೞ್ಕೆಯಿಂದೆ',
                  'ಪೊೞ್ತು ಕಳೆವಂ',
                  'ಇದು',
                  'ದೇವೇಂದ್ರಮುನೀಂದ್ರವಂದ್ಯ ಪರಮಜಿನೇಂದ್ರ ಮುಖಚಂದ್ರ',
                  'ವಾಕ್ ಚಂದ್ರಿಕಾ ಪ್ರಸರ ಪ್ರಸಾದ ಉದೀರ್ಣ',
                  'ಸೂಕ್ತಿಕಲ್ಲೋಲಮಾಲಾ ಆಕೀರ್ಣ',
                  'ಕವಿತಾ ಗುಣಾರ್ಣವ ಪ್ರಣೀತಂ ಅಪ್ಪ ಆದಿಪುರಾಣದೊಳ್',
                  'ಮಹಾಬಳ ಕುಮಾರೋದಯ ವರ್ಣನಂ',
                  'ಪ್ರಥಮ ಆಶ್ವಾಸಂ',
                  'ಸರಸ್ವತೀಮಣಿಹಾರಂ',
                  'ಕಟಕ ಕಟಿಸೂತ್ರ ಕುಂಡಲ',
                  'ಹಟತ್ ಕಿರೀಟ ಅಂದ ಆದಿ ಮಣಿಭೂಷಣ ಭಾಜಳಿತ ಮೂರ್ತಿ ಉತ್ಕರ್ಷಂ',
                  'ಸ್ಫುಟಹರ್ಷಂ',
                  'ತನ್ನ',
                  'ವರ್ಷವರ್ಧನದಿನದೊಳ್',
                  'ಅತಿಪ್ರಚಂಡ ಮಂಡಳಿಕ ಮಹಾಸಾಮಂತ ಮಂತ್ರಿ ಪ್ರಧಾನ ಪುರೋಹಿತರೂ ಅಂತರ್ವಂಶಿಕಾ',
                  'ಪರಿವಾರ ಪರಿವೃತಂ',
                  'ಉತ್ತುಂಗ ಸಿಂಹಾಸನ ಆಸೀನಂ',
                  'ಅಧಃ ಸ್ಥಿತ ಮಣಿಮಯ ಪೀಠವೇದಿಕಾ ವಿನ್ಯಸ್ತವಾಮಪಾದಂ',
                  'ಅಂಬರಚರ ಅಂಗನಾ',
                  'ಕರತಳಪಲ್ಲವ ಉಲ್ಲಸಿತ',
                  'ಹೇಮಚಾಮರ ಪವನವಿಲೋಲ ದುಕೂಲವಸನ ಪರಿವೃತಂ',
                  'ಪಂಚರತ್ನಪ್ರಭಾ ಭಾಸುರ ವಿವಿಧ ವಿಭೂಷಣ ವಿರಚಿತ',
                  'ಸುರಶರಾಸನಂ',
                  'ಒಡ್ಡೋಲಗಂ ಕೊಟ್ಟಿರೆ',
                  'ಎರಡುಂ',
                  'ವಿದ್ಯಾಧೃಶ್ರೇಢಿಯ',
                  'ಖಚರ ಮಹೀಪಾಳಕರ್',
                  'ಸುತ್ತಲುಂ',
                  'ಬಂದಿರೆ',
                  'ನಾನಾ ಆತೋದ್ಯ ವಾದ್ಯಂಗಳನೆ',
                  'ಮೆಱೆದು',
                  'ಮೆಚ್ಚಂ',
                  'ಕೊಳಲ್ ವಾದಕರ್ ಬಂದಿರೆ',
                  'ವಂದಿವ್ರಾತಂ ಎತ್ತಂ',
                  'ಗೀತ ಆರಾವದಿಂದಂ',
                  'ನೆಱೆಯೆ',
                  'ನೆಱಗೊಳಲ್',
                  'ರಕ್ತಕಂಠೀಜನಂ',
                  'ಬಗೆಗೊಳಲ್ ಇರೆ',
                  'ಚೆಲ್ವಾದುದು ಆಸ್ಥಾನರಂಗಂ',
                  'ಶ್ರೀಮತ್ ಅಮರಾಂಗನ ಆನನ',
                  'ತಾಮರಸ ಆಮೋದ',
                  'ಮತ್ತಮಧುಕರನಾ',
                  'ಸರಸ್ವತೀಮಣಿಹಾರಂ',
                  'ಸುರಸೌಖ್ಯ ಅಮೃತರಸದೊಳ್',
                  'ಬಗೆದಾಗಳೆ',
                  'ವಾಹನದೇವಿಯರ್ ಉಯ್ವರ್',
                  'ಬಾಸಿಗಂ ಒಯ್ಯನೊಯ್ಯನೆ',
                  'ಮಸುಳ್ದುವು ಆಗುಳಿಯಾಯ್ತು ಇನಿತು ಉಬ್ಬೆಗಂ',
                  'ತನ್ನ ಅಗಲ್ಕೆಗೆ',
                  'ನಾಕಲೋಕಚ್ಯುತಿಯನ್ ಆಗಳ್ ಅಱಿದು',
                  'ಮನದೊಳ್ ಅಳ್ಕಿ ಬೆಳ್ಕನೆವೋಗಿ',
                  'ಸಂತಸದ ಅಂತಮನ್ ಎಯ್ದಿ',
                  'ಸುರತಾಮೃತದೊಳ್',
                  'ತಣಿದು ಅೞ್ಕಱಿಂ',
                  'ಮೆಯ್ಗಳ್ ಎರಡಾದೊಡಂ ಏನ್ ಅಸುವೊಂದೆ',
                  'ನಿನಗೊರ್ವಂಗಲ್ಲ ಅವಸ್ಥಾಂತರ೦ ಅಮರಜನಕ್ಕೆಲ್ಲಂ ಈ',
                  'ಬಗೆಗೊಂಡು ಅಭೀತಮನನ್ ಅರ್ಚಿಸಿ'
                ]

print(len(old_kannada_sentences))
print(len(new_kannada_sentences))
# Out:
# 147
# 147

# %%
# Create vocabulary and tokenization
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(old_kannada_sentences + new_kannada_sentences)
vocab_size = len(tokenizer.word_index) + 1


# Convert sentences to sequences of integers
old_sequences = tokenizer.texts_to_sequences(old_kannada_sentences)
new_sequences = tokenizer.texts_to_sequences(new_kannada_sentences)

print(old_sequences)
print(new_sequences)
print(vocab_size)
# Out:
# [[66], [67], [68], [69], [70], [71], [72], [73], [10], [74], [75], [76], [77], [11], [78], [79], [80], [12], [13], [14], [81], [15], [82], [16], [83], [17], [18], [19], [84], [85], [86], [20], [21], [87], [88], [89], [90], [22], [23], [91], [24], [25], [26], [92], [93], [94], [95], [27], [96], [97], [98], [99], [100], [28], [101], [29], [102], [103], [30], [31], [104], [105], [106], [2], [32], [107], [108], [3], [109], [110], [111], [112], [33], [113], [34], [114], [115], [116], [117], [118], [119], [35], [36], [120], [121], [122], [123], [124], [125], [126], [4], [127], [128], [129], [130], [131], [132], [133], [134], [135], [37], [5], [38], [136], [137], [138], [139], [140], [141], [142], [143], [39], [144], [40], [145], [146], [41], [6], [147], [42], [43], [148], [149], [150], [44], [45], [46], [151], [152], [153], [154], [47], [7], [155], [48], [156], [157], [158], [159], [160], [161, 49], [162], [50], [163], [164], [165], [166]]
# [[167, 168, 51, 169], [170, 2], [171, 172], [173, 174, 175], [176, 51, 8, 1], [177, 52], [178, 179], [180, 181, 53], [10], [182, 183, 184], [185, 54], [186, 54], [52, 187], [11], [55, 188, 189, 190], [191], [192, 56, 193], [12], [13], [14], [194, 56, 195], [15], [55, 53, 57], [16], [196, 197, 58, 59], [17], [18], [19], [198, 199, 60, 200, 201, 202], [61], [203, 58, 204], [20], [21], [205], [206, 62], [207, 208], [209, 210], [22], [23], [211, 63], [24], [25], [26], [8, 212], [213, 214], [215, 216], [217, 63], [27], [218, 219, 220, 4], [221, 222], [223, 224, 225], [226, 227], [228, 229, 230, 231, 232], [28], [233, 234], [29], [235, 236, 237, 238], [239, 240, 59], [30], [31], [241, 242, 243, 244], [245, 246], [247, 1], [2], [32], [248, 1], [249, 250, 251, 1], [3], [3], [252, 1], [253, 254, 255, 62], [256, 257], [33], [258, 8, 259], [34], [260, 261, 262, 263], [264, 60, 265, 1], [266, 57, 267, 9], [268, 269, 270], [61, 271, 272], [273, 274, 275, 276], [35], [36], [277, 64, 278, 279], [280, 281], [282], [283, 284], [285, 286, 9], [287], [288, 289], [4], [290, 291, 292], [293, 294, 295, 296, 297], [298, 299], [300, 301, 302, 303, 304], [305, 306, 307], [308, 309], [7], [310, 311, 312], [313, 314, 315, 316, 317, 318, 319, 320], [37], [5], [38], [321, 322, 323, 324, 325, 326, 327], [328, 65], [329, 330, 331], [332, 333, 334, 335, 336], [337, 338], [339, 340], [341, 342, 343, 65], [344, 345, 346, 347, 348], [39], [349, 350], [40], [351], [352, 353], [41], [6], [354, 355, 356], [42], [43], [357, 358, 6], [359, 360], [361, 362], [44], [45], [46], [363, 364], [365, 366], [367, 368, 64], [369, 370], [47], [7], [371, 372], [48], [373, 374], [375, 376], [377, 378, 379, 380], [5, 381], [382, 383, 384], [385, 386, 49], [387, 388, 389], [50], [390, 391], [392, 393, 394, 395], [396, 397, 398, 9], [399, 400, 401]]
# 402

# %%
# Pad sequences to have the same length
max_seq_length = max(max(len(seq) for seq in old_sequences), max(len(seq) for seq in new_sequences))
print(max_seq_length)
old_sequences_padded = tf.keras.preprocessing.sequence.pad_sequences(old_sequences, maxlen=max_seq_length, padding='post')
new_sequences_padded = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_seq_length, padding='post')

# Create input and target sequences (shifted by one time step)
input_sequences = old_sequences_padded
target_sequences = new_sequences_padded

# Split the data into training and test sets
input_train, input_test, target_train, target_test = train_test_split(input_sequences, target_sequences, test_size=0.2, random_state=42)
print(len(input_train))
print(len(input_test))

# Define the model

# Simple-RNN -> Doesn't predict new word which is not in training data
# input_layer = Input(shape=(max_seq_length,))
# embedding_layer = Embedding(input_dim=vocab_size, output_dim=264)(input_layer)
# rnn_layer1 = SimpleRNN(units=264, return_sequences=True)(embedding_layer)
# rnn_layer2 = SimpleRNN(units=264, return_sequences=True)(rnn_layer1)
# rnn_layer3 = SimpleRNN(units=264, return_sequences=True)(rnn_layer2)
# rnn_layer4 = SimpleRNN(units=264, return_sequences=True)(rnn_layer3)
# rnn_layer5 = SimpleRNN(units=264, return_sequences=True)(rnn_layer4)
# rnn_layer6 = SimpleRNN(units=264, return_sequences=True)(rnn_layer5)
# output_layer = Dense(vocab_size, activation='softmax')(rnn_layer6)

# LSTM -> predicts new word but wrong
input_layer = Input(shape=(max_seq_length,))
embedding_layer = Embedding(input_dim=vocab_size, output_dim=800)(input_layer)
lstm_layer = LSTM(units=264, return_sequences=True)(embedding_layer)
output_layer = Dense(vocab_size, activation='softmax')(lstm_layer)

# LSTM enhanced
# input_layer = Input(shape=(max_seq_length,))
# embedding_layer = Embedding(input_dim=vocab_size, output_dim=264)(input_layer)
# bi_lstm_layer = Bidirectional(LSTM(units=264, return_sequences=True))(embedding_layer)
# dropout_layer = Dropout(0.2)(bi_lstm_layer)
# output_layer = Dense(vocab_size, activation='softmax')(dropout_layer)


# GRU -> Doesn't predict new word which is not in training data
# input_layer = Input(shape=(max_seq_length,))
# embedding_layer = Embedding(input_dim=vocab_size, output_dim=264)(input_layer)
# gru_layer = GRU(units=264, return_sequences=True)(embedding_layer)
# output_layer = Dense(vocab_size, activation='softmax')(gru_layer)
# Out:
# 8
# 117
# 30

# %%
from tensorflow.keras.utils import plot_model

model = Model(inputs=input_layer, outputs=output_layer)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# Train the model
model.fit(input_train, target_train, batch_size=32, epochs=100)
save_model(model,'model.h5')
# Out:
# Epoch 1/100
# 4/4 [==============================] - 4s 125ms/step - loss: 5.7439 - accuracy: 0.5192
# Epoch 2/100
# 4/4 [==============================] - 1s 180ms/step - loss: 4.3379 - accuracy: 0.7083
# Epoch 3/100
# 4/4 [==============================] - 1s 173ms/step - loss: 2.4953 - accuracy: 0.7083
# Epoch 4/100
# 4/4 [==============================] - 1s 159ms/step - loss: 2.1802 - accuracy: 0.7083
# Epoch 5/100
# 4/4 [==============================] - 1s 189ms/step - loss: 2.2041 - accuracy: 0.7083
# Epoch 6/100
# 4/4 [==============================] - 1s 230ms/step - loss: 2.1727 - accuracy: 0.7094
# Epoch 7/100
# 4/4 [==============================] - 1s 187ms/step - loss: 2.0910 - accuracy: 0.7094
# Epoch 8/100
# 4/4 [==============================] - 1s 205ms/step - loss: 1.9845 - accuracy: 0.7137
# Epoch 9/100
# 4/4 [==============================] - 1s 235ms/step - loss: 1.9023 - accuracy: 0.7137
# Epoch 10/100
# 4/4 [==============================] - 1s 129ms/step - loss: 1.8580 - accuracy: 0.7126
# Epoch 11/100
# 4/4 [==============================] - 1s 148ms/step - loss: 1.8591 - accuracy: 0.7105
# Epoch 12/100
# 4/4 [==============================] - 1s 132ms/step - loss: 1.8352 - accuracy: 0.7115
# Epoch 13/100
# 4/4 [==============================] - 1s 159ms/step - loss: 1.8051 - accuracy: 0.7094
# Epoch 14/100
UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   save_model(model,'model.h5')

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 8)]               0
#
#  embedding (Embedding)       (None, 8, 800)            321600
#
#  lstm (LSTM)                 (None, 8, 264)            1124640
#
#  dense (Dense)               (None, 8, 402)            106530
#
# =================================================================
# Total params: 1552770 (5.92 MB)
# Trainable params: 1552770 (5.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.save_weights('model_weights.h5')

# Save the model architecture
with open('model_architecture.json', 'w') as f:
    f.write(model.to_json())
# Save the tokenizer
with open('tokenizer.json', 'w') as f:
    f.write(tokenizer.to_json())

# %%
# Preprocess the input sentence
input_sentence = "ತಮಗಾಗದಂತೆಸಗುವರ್ಸರ್ವೋತ್ತಮರ್ಸರ್ವಸಾ"
input_sequence = tokenizer.texts_to_sequences([input_sentence])
input_sequence_padded = tf.keras.preprocessing.sequence.pad_sequences(input_sequence, maxlen=max_seq_length, padding='post')

# Predict
predicted_output_sequence = model.predict(input_sequence_padded)[0]
predicted_word_indices = np.argmax(predicted_output_sequence, axis=-1)

print(predicted_word_indices)
# Post-process the predicted sequence
predicted_words = tokenizer.sequences_to_texts([predicted_word_indices])[0]

print("Input Sentence:", input_sentence)
print("Predicted New Kannada Translation:", predicted_words)
# Out:
# 1/1 [==============================] - 1s 511ms/step
# [0 0 0 0 0 0 0 0]
# Input Sentence: ತಮಗಾಗದಂತೆಸಗುವರ್ಸರ್ವೋತ್ತಮರ್ಸರ್ವಸಾ
# Predicted New Kannada Translation:

# %%
# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(input_test, target_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 1/1 [==============================] - 0s 50ms/step - loss: 2.2890 - accuracy: 0.7667
# Test Accuracy: 76.67%

# %%
correct_predictions = 0
total_sentences = len(old_kannada_sentences)

for old_sentence, target_sentence in zip(old_kannada_sentences, new_kannada_sentences):
    # Preprocess the input sentence
    input_sequence = tokenizer.texts_to_sequences([old_sentence])
    input_sequence_padded = tf.keras.preprocessing.sequence.pad_sequences(input_sequence, maxlen=max_seq_length, padding='post')

    # Predict
    predicted_output_sequence = model.predict(input_sequence_padded)[0]
    predicted_word_indices = np.argmax(predicted_output_sequence, axis=-1)

    # Convert predicted word indices to words
    predicted_words = tokenizer.sequences_to_texts([predicted_word_indices])[0].strip()

    # Compare predicted translation to actual translation
    if predicted_words == target_sentence:
        correct_predictions += 1
    else:
        print(predicted_words, "," ,target_sentence, " ,", old_sentence)
accuracy = correct_predictions / total_sentences * 100

print(correct_predictions)
print(total_sentences)
print("Accuracy:",accuracy,"%")
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# ಈಗಳ್ , ಬಡಿಸುವೆನ್ ಇನ್ನು ಇದೊಂದು  , ಬಡಿಸುವೆನಿನ್ನಿದೊಂದು
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# ಮೆಱೆದು , ದಿವ್ಯಶರಾಳಿ ಇರ್ದುದು  , ದಿವ್ಯಶರಾಳಿಯಿರ್ದುದಿ
# 1/1 [==============================] - 0s 35ms/step
# ಜಲಕ್ಕನೆ , ಇಲ್ಲ ಒಡಮೆ  , ಲ್ಲೊಡಮೆ
# 1/1 [==============================] - 0s 37ms/step
# ಸರಸ್ವತೀಮಣಿಹಾರಂ , ಸಮಂತು  , ಸಮಂತು
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# ಸರಸ್ವತೀಮಣಿಹಾರಂ , ವಿದ್ಯಾಧೃಶ್ರೇಢಿಯ  , ವಿದ್ಯಾಧಶ್ರೇಢಿಯ
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# ಸರಸ್ವತೀಮಣಿಹಾರಂ , ಸುತ್ತಲುಂ  , ಸುತ್ತಲುಂ
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# ದೇವೇಂದ್ರಮುನೀಂದ್ರವಂದ್ಯ , ನಾನಾ ಆತೋದ್ಯ ವಾದ್ಯಂಗಳನೆ  , ನಾನಾತೋದ್ಯವಾದ್ಯಂಗಳನೆ
# 1/1 [==============================] - 0s 30ms/step
# ಸರಸ್ವತೀಮಣಿಹಾರಂ , ಮೆಱೆದು  , ಮೆಱೆದು
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# ಸರಸ್ವತೀಮಣಿಹಾರಂ , ನೆಱೆಯೆ  , ನೆಱೆಯೆ
# 1/1 [==============================] - 0s 28ms/step
# ಖಳ , ನೆಱಗೊಳಲ್  , ನೆಱಗೊಳಲ್
# 1/1 [==============================] - 0s 28ms/step
# ಸರಸ್ವತೀಮಣಿಹಾರಂ , ರಕ್ತಕಂಠೀಜನಂ  , ರಕ್ತಕಂಠೀಜನಂ
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# ಸರಸ್ವತೀಮಣಿಹಾರಂ , ಮತ್ತಮಧುಕರನಾ  , ಮತ್ತಮಧುಕರನಾ
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
#  , ಸುರಸೌಖ್ಯ ಅಮೃತರಸದೊಳ್  , ಸುರಸೌಖ್ಯಾಮೃತರಸದೊಳ್
# 1/1 [==============================] - 0s 37ms/step
# ಕರತಳಪಲ್ಲವ , ಬಗೆದಾಗಳೆ  , ಬಗೆದಾಗಳೆ
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# ಗುರುಗೆ , ತನ್ನ ಅಗಲ್ಕೆಗೆ  , ತನ್ನಗಲ್ಕೆಗೆ
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# ಮೆಱೆದು , ತಣಿದು ಅೞ್ಕಱಿಂ  , ತಣಿದೞ್ಕಱಿಂ
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 96
# 147
# Accuracy: 65.3061224489796 %

# %%
# model1 = load_model('model.h5')
from  keras.models import model_from_json

def models():
    with open('tokenizer.json') as f:
        tokenizer = tf.keras.preprocessing.text.tokenizer_from_json(f.read())

    # Model reconstruction from JSON file
    with open('model_architecture.json', 'r') as f:
        model = model_from_json(f.read())

    # Load weights into the new model
    model.load_weights('model_weights.h5')

    return model, tokenizer
model1,sequence=models()

# %%
poem = 'ಅಱಿಯಿರೆ ನೀಮುಮಾಮುಮೊಡನೋದಿದೆವೆಂಬುದನಣ್ಣ ನಿನ್ನ ನಾ ನಱಿಯೆನದೆಲ್ಲಿ ಕಂಡೆಯೊ ಮಹೀಪತಿಗಂ ದ್ವಿಜವಂಶಜಂಗಮೇ ತಱ ಕೆಳೆಯಿಂತು ನಾಣಿಲಿಗರಪ್ಪರೆ ಮಾನಸರೆಂಬ ಮಾತುಗಳ್ ನೆಱೆಗೊಳೆ ಕುಂಭಸಂಭವನನಾ ದ್ರುಪದಂ ಕಡುಸಿಗ್ಗು ಮಾಡಿದಂ'

# %%
sentence='ಸೊಗಯಿಸಿ ಬಂದ ಮಾಮರನೆ ತಳ್ತೆಲೆವಳ್ಳಿಯೆ ಪೂತಜಾತಿ ಸಂ ಪಗೆಯೆ ಕುಕಿಲ್ವ ಕೋಗಿಲೆಯೆ ಪಾಡುವ ತುಂಬಿಯೆ ನಲ್ಲರೊಳ್ಮೊಗಂ ನಗೆಮೊಗದೊಳ್ ಪಳಂಚಲೆಯೆ ಕೂಡುವ ನಲ್ಲರೆ ನೋಳ್ಪೊಡಾವ ಬೆಟ್ಟುಗಳೊಳಮಾವ ನಂದನವನಂಗಳೊಳಂ ಬನವಾಸಿ ದೇಶದೊಳ್'
sentence='ಒಡವೆಯನರ್ಥಿಗಿತ್ತೆನವನೀತಳಮಂ ಗುರುಗಿತ್ತೆನೀಗಳೊಂ ದಡೆಕೆಯುಮಿಲ್ಲ ಕೈಯೊಳೆರೆದಂ ಶ್ರುತಪಾರಗನೆಂತು ಸಂತಸಂ ಬಡಿಸುವೆನಿನ್ನಿದೊಂದು ಧನುವಿರ್ದುದು ದಿವ್ಯಶರಾಳಿಯಿರ್ದುದಿ ಲ್ಲೊಡಮೆ ಸಮಂತು ಪೇೞವರೊಳಾವುದನೀವುದೊ ಕುಂಭಸಂಭವ'
sentence='ಶ್ರೀವಿಜಯಾರ್ಧಾಚಳಖಚ ರಾವಳಿಮಣಿಮಕುಟಮಕರಿಕಾನಿಕಷಣಲೇ ಖಾವಿಳಸಿತಪದಕಮಳನಿ ಳಾವಂದ್ಯಯಶಂ ಸರಸ್ವತೀಮಣಿಹಾರಂ'
poem=sentence.strip().split()
import pickle
i=0
while(i<len(poem)):
    print(poem[i],len(poem[i]))
    if(len(poem[i])<=2 and i+1<len(poem)):
        poem[i+1]=poem[i]+poem[i+1]
        poem.remove(poem[i])
    else:
        i+=1
ans = ""
for i in poem:

    input_sequence = sequence.texts_to_sequences([i])
    input_sequence_padded = tf.keras.preprocessing.sequence.pad_sequences(input_sequence, maxlen=max_seq_length, padding='post')

    # Predict
    predicted_output_sequence = model1.predict(input_sequence_padded)[0]
    predicted_word_indices = np.argmax(predicted_output_sequence, axis=-1)

    # Convert predicted word indices to words
    predicted_words = tokenizer.sequences_to_texts([predicted_word_indices])[0].strip()
    print(predicted_words)
    if(predicted_words==""):
        ans+=i+" "
    else:
        ans+=predicted_words+" "
print(sentence)
print(ans)
def get_word_meaning(word):
    # Implement your logic to get the meaning of the word from your meanings dictionary
    # This is a placeholder, you should replace it with your actual logic
    hash_key = word
    # print(hash_key)
    with open('hash_table.pkl', 'rb') as f:
                meanings = pickle.load(f)

                # print("Meanings")
                # print(meanings)
                try:
                    print(meanings[hash_key])
                    if meanings[hash_key]==' ' or meanings[hash_key]==None:
                        return word
                    return meanings[hash_key]
                except Exception as e:
                    # print(e)
                    pass
# with open('hash_table2.pkl', 'rb') as f:
#                 meanings = pickle.load(f)
# print(meanings)
# Out:
# ಶ್ರೀವಿಜಯಾರ್ಧಾಚಳಖಚ 17
# ರಾವಳಿಮಣಿಮಕುಟಮಕರಿಕಾನಿಕಷಣಲೇ 25
# ಖಾವಿಳಸಿತಪದಕಮಳನಿ 15
# ಳಾವಂದ್ಯಯಶಂ 10
# ಸರಸ್ವತೀಮಣಿಹಾರಂ 14
# 1/1 [==============================] - 0s 500ms/step
#
# 1/1 [==============================] - 0s 27ms/step
#
# 1/1 [==============================] - 0s 27ms/step
#
# 1/1 [==============================] - 0s 28ms/step
#
# 1/1 [==============================] - 0s 29ms/step
# ಸರಸ್ವತೀಮಣಿಹಾರಂ
# ಶ್ರೀವಿಜಯಾರ್ಧಾಚಳಖಚ ರಾವಳಿಮಣಿಮಕುಟಮಕರಿಕಾನಿಕಷಣಲೇ ಖಾವಿಳಸಿತಪದಕಮಳನಿ ಳಾವಂದ್ಯಯಶಂ ಸರಸ್ವತೀಮಣಿಹಾರಂ
# ಶ್ರೀವಿಜಯಾರ್ಧಾಚಳಖಚ ರಾವಳಿಮಣಿಮಕುಟಮಕರಿಕಾನಿಕಷಣಲೇ ಖಾವಿಳಸಿತಪದಕಮಳನಿ ಳಾವಂದ್ಯಯಶಂ ಸರಸ್ವತೀಮಣಿಹಾರಂ

# %%
from  keras.models import model_from_json

def models():
    with open('models/tokenizer.json') as f:
        tokenizer = tf.keras.preprocessing.text.tokenizer_from_json(f.read())

    # Model reconstruction from JSON file
    with open('models/model_architecture.json', 'r') as f:
        model = model_from_json(f.read())

    # Load weights into the new model
    model.load_weights('models/model_weights.h5')

    return model, tokenizer

# %%
# processed_words=translation(sentence)
processed_words=ans.split()
for i in range(len(processed_words)):
    # print(processed_words[i])
    meaning = get_word_meaning(processed_words[i])
    print(meaning)
    if meaning!=None:
        processed_words[i]=meaning
print("Printing proccesed poem")
print(processed_words)
# Join the processed words back into a poem
# processed_poem = processed_words.join(',')
# processed_poem=processed_words
# print(processed_poem)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-b76d39ec52c4> in <cell line: 3>()
#       3 for i in range(len(processed_words)):
#       4     # print(processed_words[i])
# ----> 5     meaning = get_word_meaning(processed_words[i])
#       6     print(meaning)
#       7     if meaning!=None:
#
# <ipython-input-13-8044f367f1fe> in get_word_meaning(word)
#      36     hash_key = word
#      37     # print(hash_key)
# ---> 38     with open('hash_table.pkl', 'rb') as f:
#      39                 meanings = pickle.load(f)
#      40
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hash_table.pkl'

# %%
poem = sentence.strip().split()
poem

# %%
i=0
while(i<len(poem)):
    print(poem[i],len(poem[i]))
    if(len(poem[i])<=2 and i+1<len(poem)):
        poem[i+1]=poem[i]+poem[i+1]
        poem.remove(poem[i])
    else:
        i+=1
# poem

# %%
ans = ""
for i in poem:
    input_sequence = tokenizer.texts_to_sequences([i])
    input_sequence_padded = tf.keras.preprocessing.sequence.pad_sequences(input_sequence, maxlen=max_seq_length, padding='post')

    # Predict
    predicted_output_sequence = model.predict(input_sequence_padded)[0]
    predicted_word_indices = np.argmax(predicted_output_sequence, axis=-1)

    # Convert predicted word indices to words
    predicted_words = tokenizer.sequences_to_texts([predicted_word_indices])[0].strip()
    if(predicted_words==""):
        ans+=i+" "
    else:
        ans+=predicted_words+" "

ans
